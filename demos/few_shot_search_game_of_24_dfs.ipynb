# %%
from typing import Optional, List
from collections.abc import Callable
import re

# %%
from openai import OpenAI
from google.colab import userdata

client = OpenAI(api_key=userdata.get('OPENAI_API_KEY'))

# %%
def get_thought_gen_prompt(input_seq: str, state: str) -> str:
    """Get thought generation prompt.

    Keyword arguments:
    input_seq -- the input sequence (comprising four numbers, e.g., '1 1 1 8')
    state -- concatenation of all the thoughts so far (separated by '\n')"""

    # Reference: https://github.com/princeton-nlp/tree-of-thought-llm/blob/master/src/tot/tasks/game24.py
    def get_remaining_numbers(thought: str) -> str:
        return thought.split('left: ')[-1].split(')')[0]

    if state == '': # Root node; no thoughts have been generated yet.
        remaining_numbers = input_seq
    else:
        last_thought = state.strip().split('\n')[-1]
        remaining_numbers = get_remaining_numbers(last_thought)

    if remaining_numbers != '24': # Intermediate step.
        # Reference: https://github.com/princeton-nlp/tree-of-thought-llm/blob/master/src/tot/prompts/game24.py
        prompt = f'''Input: 2 8 8 14
Possible next steps:
2 + 8 = 10 (left: 8 10 14)
8 / 2 = 4 (left: 4 8 14)
14 + 2 = 16 (left: 8 8 16)
2 * 8 = 16 (left: 8 14 16)
8 - 2 = 6 (left: 6 8 14)
14 - 8 = 6 (left: 2 6 8)
14 /  2 = 7 (left: 7 8 8)
14 - 2 = 12 (left: 8 8 12)
Input: {remaining_numbers}
Possible next steps:
'''
    else: # Last (output generation) step.
        # Reference: https://github.com/princeton-nlp/tree-of-thought-llm/blob/master/src/tot/prompts/game24.py
        prompt = f'''Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Each step, you are only allowed to choose two of the remaining numbers to obtain a new number.
Input: 4 4 6 8
Steps:
4 + 8 = 12 (left: 4 6 12)
6 - 4 = 2 (left: 2 12)
2 * 12 = 24 (left: 24)
Answer: (6 - 4) * (4 + 8) = 24
Input: 2 9 10 12
Steps:
12 * 2 = 24 (left: 9 10 24)
10 - 9 = 1 (left: 1 24)
24 * 1 = 24 (left: 24)
Answer: (12 * 2) * (10 - 9) = 24
Input: 4 9 10 13
Steps:
13 - 10 = 3 (left: 3 4 9)
9 - 3 = 6 (left: 4 6)
4 * 6 = 24 (left: 24)
Answer: 4 * (9 - (13 - 10)) = 24
Input: 1 4 8 8
Steps:
8 / 4 = 2 (left: 1 2 8)
1 + 2 = 3 (left: 3 8)
3 * 8 = 24 (left: 24)
Answer: (1 + 8 / 4) * 8 = 24
Input: 5 5 5 9
Steps:
5 + 5 = 10 (left: 5 9 10)
10 + 5 = 15 (left: 9 15)
15 + 9 = 24 (left: 24)
Answer: ((5 + 5) + 5) + 9 = 24
Input: {input_seq}
Steps:
{state}
'''
    return prompt

# %%
def get_state_eval_prompt(input_seq: str, state: str) -> str:
    """Get state evaluation prompt.

    Keyword arguments:
    input_seq -- the input sequence (comprising four numbers, e.g., '1 1 1 8')
    state -- concatenation of all the thoughts so far (separated by '\n')"""

    # Reference: https://github.com/princeton-nlp/tree-of-thought-llm/blob/master/src/tot/tasks/game24.py
    def get_remaining_numbers(thought: str) -> str:
        return thought.split('left: ')[-1].split(')')[0]

    last_line = state.strip().split('\n')[-1]

    if 'left: ' not in last_line: # Last (output generation) step.
        ans = last_line.lower().replace('answer: ', '')
        # Reference: https://github.com/princeton-nlp/tree-of-thought-llm/blob/master/src/tot/prompts/game24.py
        prompt = f'''Use numbers and basic arithmetic operations (+ - * /) to obtain 24. Given an input and an answer, give a judgement (sure/impossible) if the answer is correct, i.e. it uses each input exactly once and no other numbers, and reach 24.
Input: 4 4 6 8
Answer: (4 + 8) * (6 - 4) = 24
Judge:
sure
Input: 2 9 10 12
Answer: 2 * 12 * (10 - 9) = 24
Judge:
sure
Input: 4 9 10 13
Answer: (13 - 9) * (10 - 4) = 24
Judge:
sure
Input: 4 4 6 8
Answer: (4 + 8) * (6 - 4) + 1 = 25
Judge:
impossible
Input: 2 9 10 12
Answer: 2 * (12 - 10) = 24
Judge:
impossible
Input: 4 9 10 13
Answer: (13 - 4) * (10 - 9) = 24
Judge:
impossible
Input: {input_seq}
Answer: {ans}
Judge:'''
    else: # Intermediate step.
        remaining_numbers = get_remaining_numbers(last_line)
        # Reference: https://github.com/princeton-nlp/tree-of-thought-llm/blob/master/src/tot/prompts/game24.py
        prompt = f'''Evaluate if given numbers can reach 24 (sure/likely/impossible)
10 14
10 + 14 = 24
sure
11 12
11 + 12 = 23
12 - 11 = 1
11 * 12 = 132
11 / 12 = 0.91
impossible
4 4 10
4 + 4 + 10 = 8 + 10 = 18
4 * 10 - 4 = 40 - 4 = 36
(10 - 4) * 4 = 6 * 4 = 24
sure
4 9 11
9 + 11 + 4 = 20 + 4 = 24
sure
5 7 8
5 + 7 + 8 = 12 + 8 = 20
(8 - 5) * 7 = 3 * 7 = 21
I cannot obtain 24 now, but numbers are within a reasonable range
likely
5 6 6
5 + 6 + 6 = 17
(6 - 5) * 6 = 1 * 6 = 6
I cannot obtain 24 now, but numbers are within a reasonable range
likely
10 10 11
10 + 10 + 11 = 31
(11 - 10) * 10 = 10
10 10 11 are all too big
impossible
1 3 3
1 * 3 * 3 = 9
(1 + 3) * 3 = 12
1 3 3 are all too small
impossible
{remaining_numbers}
'''
    return prompt

# %%
# Reference: https://github.com/princeton-nlp/tree-of-thought-llm/blob/master/src/tot/tasks/game24.py
def heuristic_calculator(state: str, state_evals: List[str]) -> float:
    if len(state.strip().split('\n')) == 4 and 'answer' not in state.lower(): # Such a state is undesirable.
        return 0
    value_names = [_.split('\n')[-1].lower() for _ in state_evals] # A list containing 'impossible' / 'likely' / 'sure' values.
    value_map = {'impossible': 0.001, 'likely': 1, 'sure': 20} # Ad hoc.
    value = sum(value * value_names.count(name) for name, value in value_map.items())
    return value

# %%
class FewShotSearchGameOf24DFS:
    def __init__(
            self,
            client: OpenAI,
            model: str,
            messages: List[dict],
            input_seq: str,
            get_thought_gen_prompt: Callable,
            get_state_eval_prompt: Callable,
            heuristic_calculator: Callable,
            n_evals: int = 3
    ):
        self.client = client
        self.model = model
        self.messages = messages
        self.input_seq = input_seq
        self.messages.append({'role': "user", 'content': input_seq})
        self.get_thought_gen_prompt = get_thought_gen_prompt # For consumption of the thought generator.
        self.get_state_eval_prompt = get_state_eval_prompt # For consumption of the state evaluator.
        self.heuristic_calculator = heuristic_calculator # For consumption of the state evaluator.
        self.n_evals = n_evals # For consumption of the state evaluator.

    def chat_completion(
            self,
            messages: List[dict],
            model: str,
            temperature: float = 0.2,
            max_tokens: int = 4096,
            n: int = 1,
            stop: str = "\nObservation:",
            **kwargs
    ) -> str:
        response = self.client.chat.completions.create(
            messages=messages,
            model=model,
            temperature=temperature,
            max_tokens=max_tokens,
            n=n,
            stop=stop,
            **kwargs
        )
        return response.choices[0].message.content

    def thought_generator(self, state: str) -> str: # Tool.
        prompt = self.get_thought_gen_prompt(self.input_seq, state)
        # The text generation parameters are the same as: https://github.com/princeton-nlp/tree-of-thought-llm/blob/master/src/tot/models.py
        thoughts = self.chat_completion([{'role': "user", 'content': prompt}], model="gpt-4", temperature=0.7, max_tokens=1000, n=1, stop=None)
        # Note: Due to the template of the thought generation prompt, each thought will appear on a new line.
        return thoughts

    def state_evaluator(self, state: str) -> float: # Tool.
        prompt = self.get_state_eval_prompt(self.input_seq, state)
        state_evals = []
        for _ in range(self.n_evals):
            # The text generation parameters are the same as: https://github.com/princeton-nlp/tree-of-thought-llm/blob/master/src/tot/models.py
            state_eval = self.chat_completion([{'role': "user", 'content': prompt}], model="gpt-4", temperature=0.7, max_tokens=1000, n=1, stop=None)
            state_evals.append(state_eval)
        value = self.heuristic_calculator(state, state_evals)
        return value

    def backtrack(self, from_node: str, to_node: str, flag: bool) -> str:
        """A dummy tool that doesn't do anything in this notebook.
        However, in the evaluation notebook, the `backtrack` method is used to perform various 'correctness checks' related to backtracking."""

        return "Ok."

    def react_loop(self, step_limit: Optional[int] = None) -> str:
        i = 0
        while True:
            if step_limit is not None and i >= step_limit:
                print("Step limit reached! Breaking the ReAct loop...")
                break
            completion = self.chat_completion(self.messages, model=self.model)
            print(completion)
            print("---")
            if "We're now outside the tree." in completion:
                self.messages.append({'role': "assistant", 'content': completion})
                return "-- end of search --"
            else: # A tool call was made.
                tool_call_string = completion.split('Action: ')[-1].strip()
                if 'thought_generator' in tool_call_string or 'state_evaluator' in tool_call_string or 'backtrack' in tool_call_string:
                    tool_call_string = tool_call_string.replace('thought_generator', 'self.thought_generator')
                    tool_call_string = tool_call_string.replace('state_evaluator', 'self.state_evaluator')
                    tool_call_string = tool_call_string.replace('backtrack', 'self.backtrack')
                    result = eval(tool_call_string)
                    print(result)
                    print("---")
                else:
                    raise AssertionError("Invalid tool call string!")
                completion += "\nObservation:\n"
                self.messages.append({'role': "assistant", 'content': completion})
                self.messages.append({'role': "user", 'content': str(result)})
            i += 1

# %% [markdown]
# Let's fetch the few-shot examples.

# %%
# !git clone https://github.com/sambitmukherjee/few-shot-search.git
# Out:
# fatal: destination path 'few-shot-search' already exists and is not an empty directory.

# %%
# %cd few-shot-search
# Out:
# /content/few-shot-search

# %%
from few_shot_examples.game_of_24_dfs_4_shot_examples import *

# %%
len(messages)
# Out:
# 210

# %%
messages[0]
# Out:
# {'role': 'user',
#  'content': 'Four numbers: 1 1 9 9\n\nSearch parameters:-\nHeuristic threshold: 3.0\nLevel limit: 3'}

# %%
messages[-1]
# Out:
# {'role': 'assistant',
#  'content': "---\n~~~\nWe're now outside the tree.\n\nFlag received: True"}

# %%
system_prompt = """Your task is to role-play a particular type of tree search algorithm.

To help you mimic this algorithm successfully, you will be provided few-shot examples. Study these examples carefully to learn how to mimic the algorithm successfully.
You must adhere to the reasoning style and choice of words in these few-shot examples. Do not use any new words that aren't present in the few-shot examples.

If at any point, you think that you have found the final solution (i.e., the search is over), you must still backtrack all the way up the tree (as shown in the few-shot examples). Do not fail to do this."""

# %%
messages = [{'role': "system", 'content': system_prompt}] + messages

# %% [markdown]
# First, let's check the search trace on four numbers that cannot reach 24. (Please feel free to replace the below puzzle with a different set of four numbers that cannot reach 24.)

# %%
new_input_seq1 = '''Four numbers: 1 8 12 13

Search parameters:-
Heuristic threshold: 3.0
Level limit: 3'''

# %%
few_shot_search = FewShotSearchGameOf24DFS(client, "gpt-4o", messages, new_input_seq1, get_thought_gen_prompt, get_state_eval_prompt, heuristic_calculator)

# %%
few_shot_search.react_loop()
# Out:
# Starting the tree search...
# ---
# ~~~
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Using the thought generator tool to obtain thought candidates...
#
# Action: thought_generator('')
#
# ---
# 1 + 8 = 9 (left: 9 12 13)
# 8 - 1 = 7 (left: 7 12 13)
# 12 - 1 = 11 (left: 8 11 13)
# 13 - 1 = 12 (left: 8 12 12)
# 1 * 8 = 8 (left: 8 12 13)
# 12 / 1 = 12 (left: 8 12 13)
# 13 / 1 = 13 (left: 8 12 13)
# 12 + 1 = 13 (left: 8 13 13)
# 13 - 8 = 5 (left: 1 5 12)
# 13 - 12 = 1 (left: 1 1 8)
# 8 * 1 = 8 (left: 8 12 13)
# 12 - 8 = 4 (left: 1 4 13)
# 13 / 8 = 1.625 (left: 1 1.625 12)
# 12 * 1 = 12 (left: 8 12 13)
# 13 * 1 = 13 (left: 8 12 13)
# ---
# Each of the above thought candidates has been added as a child node of the current node:
#
# Node 0_0: 1 + 8 = 9 (left: 9 12 13)
# Node 0_1: 8 - 1 = 7 (left: 7 12 13)
# Node 0_2: 12 - 1 = 11 (left: 8 11 13)
# Node 0_3: 13 - 1 = 12 (left: 8 12 12)
# Node 0_4: 1 * 8 = 8 (left: 8 12 13)
# Node 0_5: 12 / 1 = 12 (left: 8 12 13)
# Node 0_6: 13 / 1 = 13 (left: 8 12 13)
# Node 0_7: 12 + 1 = 13 (left: 8 13 13)
# Node 0_8: 13 - 8 = 5 (left: 1 5 12)
# Node 0_9: 13 - 12 = 1 (left: 1 1 8)
# Node 0_10: 8 * 1 = 8 (left: 8 12 13)
# Node 0_11: 12 - 8 = 4 (left: 1 4 13)
# Node 0_12: 13 / 8 = 1.625 (left: 1 1.625 12)
# Node 0_13: 12 * 1 = 12 (left: 8 12 13)
# Node 0_14: 13 * 1 = 13 (left: 8 12 13)
#
# Looping through the child nodes one at a time...
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_0
# State of current child:
# 1 + 8 = 9 (left: 9 12 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''1 + 8 = 9 (left: 9 12 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_1
# State of current child:
# 8 - 1 = 7 (left: 7 12 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''8 - 1 = 7 (left: 7 12 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_2
# State of current child:
# 12 - 1 = 11 (left: 8 11 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''12 - 1 = 11 (left: 8 11 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_3
# State of current child:
# 13 - 1 = 12 (left: 8 12 12)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 1 = 12 (left: 8 12 12)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_4
# State of current child:
# 1 * 8 = 8 (left: 8 12 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''1 * 8 = 8 (left: 8 12 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_5
# State of current child:
# 12 / 1 = 12 (left: 8 12 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''12 / 1 = 12 (left: 8 12 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_6
# State of current child:
# 13 / 1 = 13 (left: 8 12 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 / 1 = 13 (left: 8 12 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_7
# State of current child:
# 12 + 1 = 13 (left: 8 13 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''12 + 1 = 13 (left: 8 13 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_8
# State of current child:
# 13 - 8 = 5 (left: 1 5 12)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 8 = 5 (left: 1 5 12)''')
#
# ---
# 3.0
# ---
# Heuristic value of current child: 3.0
#
# 3.0 >= 3.0
#
# Heuristic value satisfies the minimum required threshold of 3.0.
#
# Checking whether the current level is greater than or equal to the level limit...
#
# Current level: 0
#
# Level limit: 3
#
# 0 < 3
#
# No it isn't. The search isn't over yet. Searching subtree.
# ---
# ~~~
# Current level: 1
# Index of current node: 0_8
# State of current node:
# 13 - 8 = 5 (left: 1 5 12)
#
# Using the thought generator tool to obtain thought candidates...
#
# Action: thought_generator('''13 - 8 = 5 (left: 1 5 12)''')
#
# ---
# 1 + 5 = 6 (left: 6 12)
# 12 - 5 = 7 (left: 1 7)
# 12 / 1 = 12 (left: 5 12)
# 5 * 1 = 5 (left: 5 12)
# 12 - 1 = 11 (left: 5 11)
# 5 - 1 = 4 (left: 4 12)
# 1 * 5 = 5 (left: 5 12)
# 5 + 1 = 6 (left: 6 12)
# ---
# Each of the above thought candidates has been added as a child node of the current node:
#
# Node 0_8_0: 1 + 5 = 6 (left: 6 12)
# Node 0_8_1: 12 - 5 = 7 (left: 1 7)
# Node 0_8_2: 12 / 1 = 12 (left: 5 12)
# Node 0_8_3: 5 * 1 = 5 (left: 5 12)
# Node 0_8_4: 12 - 1 = 11 (left: 5 11)
# Node 0_8_5: 5 - 1 = 4 (left: 4 12)
# Node 0_8_6: 1 * 5 = 5 (left: 5 12)
# Node 0_8_7: 5 + 1 = 6 (left: 6 12)
#
# Looping through the child nodes one at a time...
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_8
# State of current node:
# 13 - 8 = 5 (left: 1 5 12)
#
# Index of current child: 0_8_0
# State of current child:
# 13 - 8 = 5 (left: 1 5 12)
# 1 + 5 = 6 (left: 6 12)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 8 = 5 (left: 1 5 12)
# 1 + 5 = 6 (left: 6 12)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_8
# State of current node:
# 13 - 8 = 5 (left: 1 5 12)
#
# Index of current child: 0_8_1
# State of current child:
# 13 - 8 = 5 (left: 1 5 12)
# 12 - 5 = 7 (left: 1 7)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 8 = 5 (left: 1 5 12)
# 12 - 5 = 7 (left: 1 7)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_8
# State of current node:
# 13 - 8 = 5 (left: 1 5 12)
#
# Index of current child: 0_8_2
# State of current child:
# 13 - 8 = 5 (left: 1 5 12)
# 12 / 1 = 12 (left: 5 12)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 8 = 5 (left: 1 5 12)
# 12 / 1 = 12 (left: 5 12)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_8
# State of current node:
# 13 - 8 = 5 (left: 1 5 12)
#
# Index of current child: 0_8_3
# State of current child:
# 13 - 8 = 5 (left: 1 5 12)
# 5 * 1 = 5 (left: 5 12)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 8 = 5 (left: 1 5 12)
# 5 * 1 = 5 (left: 5 12)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_8
# State of current node:
# 13 - 8 = 5 (left: 1 5 12)
#
# Index of current child: 0_8_4
# State of current child:
# 13 - 8 = 5 (left: 1 5 12)
# 12 - 1 = 11 (left: 5 11)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 8 = 5 (left: 1 5 12)
# 12 - 1 = 11 (left: 5 11)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_8
# State of current node:
# 13 - 8 = 5 (left: 1 5 12)
#
# Index of current child: 0_8_5
# State of current child:
# 13 - 8 = 5 (left: 1 5 12)
# 5 - 1 = 4 (left: 4 12)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 8 = 5 (left: 1 5 12)
# 5 - 1 = 4 (left: 4 12)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_8
# State of current node:
# 13 - 8 = 5 (left: 1 5 12)
#
# Index of current child: 0_8_6
# State of current child:
# 13 - 8 = 5 (left: 1 5 12)
# 1 * 5 = 5 (left: 5 12)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 8 = 5 (left: 1 5 12)
# 1 * 5 = 5 (left: 5 12)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_8
# State of current node:
# 13 - 8 = 5 (left: 1 5 12)
#
# Index of current child: 0_8_7
# State of current child:
# 13 - 8 = 5 (left: 1 5 12)
# 5 + 1 = 6 (left: 6 12)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 8 = 5 (left: 1 5 12)
# 5 + 1 = 6 (left: 6 12)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# No more children remaining. All child nodes have been looped through.
#
# None of the child nodes led to success. Seems like a dead end.
#
# It's time to backtrack.
#
# Reminder:-
# Current level: 1
# Index of current node: 0_8
#
# Backtracking with flag False.
#
# Action: backtrack(from_node='''0_8''', to_node='''0''', flag=False)
#
# ---
# Ok.
# ---
# ---
# ~~~
# We're back at node: 0
#
# Flag received: False
#
# That is, searching the subtree starting at child node 0_8 was unsuccessful!
#
# Trying the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_9
# State of current child:
# 13 - 12 = 1 (left: 1 1 8)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 12 = 1 (left: 1 1 8)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_10
# State of current child:
# 8 * 1 = 8 (left: 8 12 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''8 * 1 = 8 (left: 8 12 13)''')
#
# ---
# 1.002
# ---
# Heuristic value of current child: 1.002
#
# 1.002 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_11
# State of current child:
# 12 - 8 = 4 (left: 1 4 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''12 - 8 = 4 (left: 1 4 13)''')
#
# ---
# 3.0
# ---
# Heuristic value of current child: 3.0
#
# 3.0 >= 3.0
#
# Heuristic value satisfies the minimum required threshold of 3.0.
#
# Checking whether the current level is greater than or equal to the level limit...
#
# Current level: 0
#
# Level limit: 3
#
# 0 < 3
#
# No it isn't. The search isn't over yet. Searching subtree.
# ---
# ~~~
# Current level: 1
# Index of current node: 0_11
# State of current node:
# 12 - 8 = 4 (left: 1 4 13)
#
# Using the thought generator tool to obtain thought candidates...
#
# Action: thought_generator('''12 - 8 = 4 (left: 1 4 13)''')
#
# ---
# 1 + 4 = 5 (left: 5 13)
# 4 - 1 = 3 (left: 3 13)
# 13 - 1 = 12 (left: 4 12)
# 13 - 4 = 9 (left: 1 9)
# 4 * 1 = 4 (left: 4 13)
# 13 / 1 = 13 (left: 4 13)
# 13 + 1 = 14 (left: 4 14)
# 1 * 4 = 4 (left: 4 13)
# ---
# Each of the above thought candidates has been added as a child node of the current node:
#
# Node 0_11_0: 1 + 4 = 5 (left: 5 13)
# Node 0_11_1: 4 - 1 = 3 (left: 3 13)
# Node 0_11_2: 13 - 1 = 12 (left: 4 12)
# Node 0_11_3: 13 - 4 = 9 (left: 1 9)
# Node 0_11_4: 4 * 1 = 4 (left: 4 13)
# Node 0_11_5: 13 / 1 = 13 (left: 4 13)
# Node 0_11_6: 13 + 1 = 14 (left: 4 14)
# Node 0_11_7: 1 * 4 = 4 (left: 4 13)
#
# Looping through the child nodes one at a time...
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_11
# State of current node:
# 12 - 8 = 4 (left: 1 4 13)
#
# Index of current child: 0_11_0
# State of current child:
# 12 - 8 = 4 (left: 1 4 13)
# 1 + 4 = 5 (left: 5 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''12 - 8 = 4 (left: 1 4 13)
# 1 + 4 = 5 (left: 5 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_11
# State of current node:
# 12 - 8 = 4 (left: 1 4 13)
#
# Index of current child: 0_11_1
# State of current child:
# 12 - 8 = 4 (left: 1 4 13)
# 4 - 1 = 3 (left: 3 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''12 - 8 = 4 (left: 1 4 13)
# 4 - 1 = 3 (left: 3 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_11
# State of current node:
# 12 - 8 = 4 (left: 1 4 13)
#
# Index of current child: 0_11_2
# State of current child:
# 12 - 8 = 4 (left: 1 4 13)
# 13 - 1 = 12 (left: 4 12)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''12 - 8 = 4 (left: 1 4 13)
# 13 - 1 = 12 (left: 4 12)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_11
# State of current node:
# 12 - 8 = 4 (left: 1 4 13)
#
# Index of current child: 0_11_3
# State of current child:
# 12 - 8 = 4 (left: 1 4 13)
# 13 - 4 = 9 (left: 1 9)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''12 - 8 = 4 (left: 1 4 13)
# 13 - 4 = 9 (left: 1 9)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_11
# State of current node:
# 12 - 8 = 4 (left: 1 4 13)
#
# Index of current child: 0_11_4
# State of current child:
# 12 - 8 = 4 (left: 1 4 13)
# 4 * 1 = 4 (left: 4 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''12 - 8 = 4 (left: 1 4 13)
# 4 * 1 = 4 (left: 4 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_11
# State of current node:
# 12 - 8 = 4 (left: 1 4 13)
#
# Index of current child: 0_11_5
# State of current child:
# 12 - 8 = 4 (left: 1 4 13)
# 13 / 1 = 13 (left: 4 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''12 - 8 = 4 (left: 1 4 13)
# 13 / 1 = 13 (left: 4 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_11
# State of current node:
# 12 - 8 = 4 (left: 1 4 13)
#
# Index of current child: 0_11_6
# State of current child:
# 12 - 8 = 4 (left: 1 4 13)
# 13 + 1 = 14 (left: 4 14)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''12 - 8 = 4 (left: 1 4 13)
# 13 + 1 = 14 (left: 4 14)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_11
# State of current node:
# 12 - 8 = 4 (left: 1 4 13)
#
# Index of current child: 0_11_7
# State of current child:
# 12 - 8 = 4 (left: 1 4 13)
# 1 * 4 = 4 (left: 4 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''12 - 8 = 4 (left: 1 4 13)
# 1 * 4 = 4 (left: 4 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# No more children remaining. All child nodes have been looped through.
#
# None of the child nodes led to success. Seems like a dead end.
#
# It's time to backtrack.
#
# Reminder:-
# Current level: 1
# Index of current node: 0_11
#
# Backtracking with flag False.
#
# Action: backtrack(from_node='''0_11''', to_node='''0''', flag=False)
#
# ---
# Ok.
# ---
# ---
# ~~~
# We're back at node: 0
#
# Flag received: False
#
# That is, searching the subtree starting at child node 0_11 was unsuccessful!
#
# Trying the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_12
# State of current child:
# 13 / 8 = 1.625 (left: 1 1.625 12)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 / 8 = 1.625 (left: 1 1.625 12)''')
#
# ---
# 2.001
# ---
# Heuristic value of current child: 2.001
#
# 2.001 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_13
# State of current child:
# 12 * 1 = 12 (left: 8 12 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''12 * 1 = 12 (left: 8 12 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_14
# State of current child:
# 13 * 1 = 13 (left: 8 12 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 * 1 = 13 (left: 8 12 13)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# No more children remaining. All child nodes have been looped through.
#
# None of the child nodes led to success. Seems like a dead end.
#
# It's time to backtrack.
#
# Reminder:-
# Current level: 0
# Index of current node: 0
#
# Backtracking with flag False.
#
# Action: backtrack(from_node='''0''', to_node=None, flag=False)
#
# ---
# Ok.
# ---
# ---
# ~~~
# We're now outside the tree.
#
# Flag received: False
# ---
# '-- end of search --'

# %% [markdown]
# Now, let's check the search trace on four numbers that can reach 24. (Please feel free to replace the below puzzle with a different puzzle from: https://github.com/sambitmukherjee/tree-of-thought-llm/blob/master/src/tot/data/24/24.csv)

# %%
new_input_seq2 = '''Four numbers: 11 11 11 13

Search parameters:-
Heuristic threshold: 3.0
Level limit: 3'''

# %%
few_shot_search = FewShotSearchGameOf24DFS(client, "gpt-4o", messages, new_input_seq2, get_thought_gen_prompt, get_state_eval_prompt, heuristic_calculator)

# %%
few_shot_search.react_loop()
# Out:
# Starting the tree search...
# ---
# ~~~
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Using the thought generator tool to obtain thought candidates...
#
# Action: thought_generator('')
#
# ---
# 11 + 11 = 22 (left: 11 13 22)
# 11 * 11 = 121 (left: 11 13 121)
# 13 - 11 = 2 (left: 2 11 11)
# 11 / 11 = 1 (left: 1 11 13)
# 13 + 11 = 24 (left: 11 11 24)
# 13 * 11 = 143 (left: 11 11 143)
# ---
# Each of the above thought candidates has been added as a child node of the current node:
#
# Node 0_0: 11 + 11 = 22 (left: 11 13 22)
# Node 0_1: 11 * 11 = 121 (left: 11 13 121)
# Node 0_2: 13 - 11 = 2 (left: 2 11 11)
# Node 0_3: 11 / 11 = 1 (left: 1 11 13)
# Node 0_4: 13 + 11 = 24 (left: 11 11 24)
# Node 0_5: 13 * 11 = 143 (left: 11 11 143)
#
# Looping through the child nodes one at a time...
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_0
# State of current child:
# 11 + 11 = 22 (left: 11 13 22)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''11 + 11 = 22 (left: 11 13 22)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_1
# State of current child:
# 11 * 11 = 121 (left: 11 13 121)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''11 * 11 = 121 (left: 11 13 121)''')
#
# ---
# 0.003
# ---
# Heuristic value of current child: 0.003
#
# 0.003 < 3.0
#
# Heuristic value fails to satisfy the minimum required threshold of 3.0. Moving on to the next child.
# ---
# Reminder:-
# Current level: 0
# Index of current node: 0
# State of current node:
# '' (empty string; no thoughts have been generated yet as we're still at the root node)
#
# Index of current child: 0_2
# State of current child:
# 13 - 11 = 2 (left: 2 11 11)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 11 = 2 (left: 2 11 11)''')
#
# ---
# 20.002
# ---
# Heuristic value of current child: 20.002
#
# 20.002 >= 3.0
#
# Heuristic value satisfies the minimum required threshold of 3.0.
#
# Checking whether the current level is greater than or equal to the level limit...
#
# Current level: 0
#
# Level limit: 3
#
# 0 < 3
#
# No it isn't. The search isn't over yet. Searching subtree.
# ---
# ~~~
# Current level: 1
# Index of current node: 0_2
# State of current node:
# 13 - 11 = 2 (left: 2 11 11)
#
# Using the thought generator tool to obtain thought candidates...
#
# Action: thought_generator('''13 - 11 = 2 (left: 2 11 11)''')
#
# ---
# 2 + 11 = 13 (left: 11 13)
# 11 - 2 = 9 (left: 9 11)
# 11 /  2 = 5.5 (left: 2 5.5)
# 2 * 11 = 22 (left: 11 22)
# 11 + 2 = 13 (left: 11 13)
# ---
# Each of the above thought candidates has been added as a child node of the current node:
#
# Node 0_2_0: 2 + 11 = 13 (left: 11 13)
# Node 0_2_1: 11 - 2 = 9 (left: 9 11)
# Node 0_2_2: 11 / 2 = 5.5 (left: 2 5.5)
# Node 0_2_3: 2 * 11 = 22 (left: 11 22)
# Node 0_2_4: 11 + 2 = 13 (left: 11 13)
#
# Looping through the child nodes one at a time...
# ---
# Reminder:-
# Current level: 1
# Index of current node: 0_2
# State of current node:
# 13 - 11 = 2 (left: 2 11 11)
#
# Index of current child: 0_2_0
# State of current child:
# 13 - 11 = 2 (left: 2 11 11)
# 2 + 11 = 13 (left: 11 13)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 11 = 2 (left: 2 11 11)
# 2 + 11 = 13 (left: 11 13)''')
#
# ---
# 60.0
# ---
# Heuristic value of current child: 60.0
#
# 60.0 >= 3.0
#
# Heuristic value satisfies the minimum required threshold of 3.0.
#
# Checking whether the current level is greater than or equal to the level limit...
#
# Current level: 1
#
# Level limit: 3
#
# 1 < 3
#
# No it isn't. The search isn't over yet. Searching subtree.
# ---
# ~~~
# Current level: 2
# Index of current node: 0_2_0
# State of current node:
# 13 - 11 = 2 (left: 2 11 11)
# 2 + 11 = 13 (left: 11 13)
#
# Using the thought generator tool to obtain thought candidates...
#
# Action: thought_generator('''13 - 11 = 2 (left: 2 11 11)
# 2 + 11 = 13 (left: 11 13)''')
#
# ---
# 11 + 13 = 24 (left: 24)
# 13 - 11 = 2 (left: 2)
# 11 * 13 = 143 (left: 143)
# 13 / 11 = 1.18 (left: 1.18)
# ---
# Each of the above thought candidates has been added as a child node of the current node:
#
# Node 0_2_0_0: 11 + 13 = 24 (left: 24)
# Node 0_2_0_1: 13 - 11 = 2 (left: 2)
# Node 0_2_0_2: 11 * 13 = 143 (left: 143)
# Node 0_2_0_3: 13 / 11 = 1.18 (left: 1.18)
#
# Looping through the child nodes one at a time...
# ---
# Reminder:-
# Current level: 2
# Index of current node: 0_2_0
# State of current node:
# 13 - 11 = 2 (left: 2 11 11)
# 2 + 11 = 13 (left: 11 13)
#
# Index of current child: 0_2_0_0
# State of current child:
# 13 - 11 = 2 (left: 2 11 11)
# 2 + 11 = 13 (left: 11 13)
# 11 + 13 = 24 (left: 24)
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 11 = 2 (left: 2 11 11)
# 2 + 11 = 13 (left: 11 13)
# 11 + 13 = 24 (left: 24)''')
#
# ---
# 40.0
# ---
# Heuristic value of current child: 40.0
#
# 40.0 >= 3.0
#
# Heuristic value satisfies the minimum required threshold of 3.0.
#
# Checking whether the current level is greater than or equal to the level limit...
#
# Current level: 2
#
# Level limit: 3
#
# 2 < 3
#
# No it isn't. The search isn't over yet. Searching subtree.
# ---
# ~~~
# Current level: 3
# Index of current node: 0_2_0_0
# State of current node:
# 13 - 11 = 2 (left: 2 11 11)
# 2 + 11 = 13 (left: 11 13)
# 11 + 13 = 24 (left: 24)
#
# Using the thought generator tool to obtain thought candidates...
#
# Action: thought_generator('''13 - 11 = 2 (left: 2 11 11)
# 2 + 11 = 13 (left: 11 13)
# 11 + 13 = 24 (left: 24)''')
#
# ---
# Answer: (13 - 11) + 11 + 11 = 24
# ---
# Each of the above thought candidates has been added as a child node of the current node:
#
# Node 0_2_0_0_0: Answer: (13 - 11) + 11 + 11 = 24
#
# Looping through the child nodes one at a time...
# ---
# Reminder:-
# Current level: 3
# Index of current node: 0_2_0_0
# State of current node:
# 13 - 11 = 2 (left: 2 11 11)
# 2 + 11 = 13 (left: 11 13)
# 11 + 13 = 24 (left: 24)
#
# Index of current child: 0_2_0_0_0
# State of current child:
# 13 - 11 = 2 (left: 2 11 11)
# 2 + 11 = 13 (left: 11 13)
# 11 + 13 = 24 (left: 24)
# Answer: (13 - 11) + 11 + 11 = 24
#
# Using the state evaluator tool to obtain heuristic value...
#
# Action: state_evaluator('''13 - 11 = 2 (left: 2 11 11)
# 2 + 11 = 13 (left: 11 13)
# 11 + 13 = 24 (left: 24)
# Answer: (13 - 11) + 11 + 11 = 24''')
#
# ---
# 60.0
# ---
# Heuristic value of current child: 60.0
#
# 60.0 >= 3.0
#
# Heuristic value satisfies the minimum required threshold of 3.0.
#
# Checking whether the current level is greater than or equal to the level limit...
#
# Current level: 3
#
# Level limit: 3
#
# 3 >= 3
#
# Yes it is. The search is over. Printing the state of the current child as the final solution...
#
# Final solution:-
# 13 - 11 = 2 (left: 2 11 11)
# 2 + 11 = 13 (left: 11 13)
# 11 + 13 = 24 (left: 24)
# Answer: (13 - 11) + 11 + 11 = 24
#
# It's time to backtrack.
#
# Reminder:-
# Current level: 3
# Index of current node: 0_2_0_0
#
# Backtracking with flag True.
#
# Action: backtrack(from_node='''0_2_0_0''', to_node='''0_2_0''', flag=True)
#
# ---
# Ok.
# ---
# ---
# ~~~
# We're back at node: 0_2_0
#
# Flag received: True
#
# That is, searching the subtree starting at child node 0_2_0_0 was successful!
#
# It's time to backtrack.
#
# Reminder:-
# Current level: 2
# Index of current node: 0_2_0
#
# Backtracking with flag True.
#
# Action: backtrack(from_node='''0_2_0''', to_node='''0_2''', flag=True)
#
# ---
# Ok.
# ---
# ---
# ~~~
# We're back at node: 0_2
#
# Flag received: True
#
# That is, searching the subtree starting at child node 0_2_0 was successful!
#
# It's time to backtrack.
#
# Reminder:-
# Current level: 1
# Index of current node: 0_2
#
# Backtracking with flag True.
#
# Action: backtrack(from_node='''0_2''', to_node='''0''', flag=True)
#
# ---
# Ok.
# ---
# ---
# ~~~
# We're back at node: 0
#
# Flag received: True
#
# That is, searching the subtree starting at child node 0_2 was successful!
#
# It's time to backtrack.
#
# Reminder:-
# Current level: 0
# Index of current node: 0
#
# Backtracking with flag True.
#
# Action: backtrack(from_node='''0''', to_node=None, flag=True)
#
# ---
# Ok.
# ---
# ---
# ~~~
# We're now outside the tree.
#
# Flag received: True
# ---
# '-- end of search --'
